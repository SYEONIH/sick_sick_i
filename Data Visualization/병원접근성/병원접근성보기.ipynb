# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# C:\Users\ParkChunSoo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
pop = pd.read_csv("행정구역_시군구_별__성별_인구수_20240225200520.csv", encoding='UTF-8')
pop = pop.drop(pop.index[0])
pop
# Out:
#    행정구역(시군구)별   2023.12
# 1          전국  51325329
# 2       서울특별시   9386034
# 3       부산광역시   3293362
# 4       대구광역시   2374960
# 5       인천광역시   2997410
# 6       광주광역시   1419237
# 7       대전광역시   1442216
# 8       울산광역시   1103661
# 9     세종특별자치시    386525
# 10        경기도  13630821
# 11    강원특별자치도   1527807
# 12       충청북도   1593469
# 13       충청남도   2130119
# 14    전북특별자치도   1754757
# 15       전라남도   1804217
# 16       경상북도   2554324
# 17       경상남도   3251158
# 18    제주특별자치도    675252

# %%
hos = pd.read_csv("병원목록(2023년12월).csv", encoding='UTF-8', error_bad_lines=False)
hos
# Out:
# C:\Users\PARKCH~1\AppData\Local\Temp/ipykernel_19004/332985682.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   hos = pd.read_csv("병원목록(2023년12월).csv", encoding='UTF-8', error_bad_lines=False)
#                                                  암호화요양기호         요양기관명  총의사수  \
# 0      JDQ4MTg4MSM1MSMkMSMkMCMkNzIkNDgxNzAyIzExIyQxIy...     서울닥터우치과의원   1.0
# 1      JDQ4MTg4MSM1MSMkMSMkMCMkNzIkNDgxNzAyIzExIyQxIy...      이가튼튼치과의원   1.0
# 2      JDQ4MTg4MSM1MSMkMSMkMCMkNzIkNDgxNzAyIzIxIyQxIy...       에이스치과의원   1.0
# 3      JDQ4MTg4MSM1MSMkMSMkMCMkNzIkNDgxNzAyIzMxIyQyIy...     서울더좋은치과의원   1.0
# 4      JDQ4MTg4MSM1MSMkMSMkMCMkNzIkNDgxNzAyIzMxIyQyIy...     연세유라인치과의원   1.0
# ...                                                  ...           ...   ...
# 73367  JDQ4MTAxMiM1MSMkMSMkMCMkNzIkMzgxOTYxIzIxIyQyIy...       신서경치과의원   1.0
# ...

# %%
pop['병원수']=['73372','18609','5432','4019','3629','2265','2287','1404','435','16858','1713','1955','2420','2560','2127','2881','3820','958']
#pop['병원수']=['18609','5432','4019','3629','2265','2287','1404','435','16858','1713','1955','2420','2560','2127','2881','3820','958']
pop
# Out:
#    행정구역(시군구)별   2023.12    병원수
# 1          전국  51325329  73372
# 2       서울특별시   9386034  18609
# 3       부산광역시   3293362   5432
# 4       대구광역시   2374960   4019
# 5       인천광역시   2997410   3629
# 6       광주광역시   1419237   2265
# 7       대전광역시   1442216   2287
# 8       울산광역시   1103661   1404
# 9     세종특별자치시    386525    435
# 10        경기도  13630821  16858
# 11    강원특별자치도   1527807   1713
# 12       충청북도   1593469   1955
# 13       충청남도   2130119   2420
# 14    전북특별자치도   1754757   2560
# 15       전라남도   1804217   2127
# 16       경상북도   2554324   2881
# 17       경상남도   3251158   3820
# 18    제주특별자치도    675252    958

# %%
temp = []
for i in range(1, len(pop)+1):
    temp.append(float(pop['2023.12'][i])/float(pop['병원수'][i]))
pop['병원 1개당 인구수']=temp
pop
# Out:
#    행정구역(시군구)별   2023.12    병원수  병원 1개당 인구수
# 1          전국  51325329  73372  699.522011
# 2       서울특별시   9386034  18609  504.381428
# 3       부산광역시   3293362   5432  606.289028
# 4       대구광역시   2374960   4019  590.933068
# 5       인천광역시   2997410   3629  825.960320
# 6       광주광역시   1419237   2265  626.594702
# 7       대전광역시   1442216   2287  630.614779
# 8       울산광역시   1103661   1404  786.083333
# 9     세종특별자치시    386525    435  888.563218
# 10        경기도  13630821  16858  808.566912
# 11    강원특별자치도   1527807   1713  891.889667
# 12       충청북도   1593469   1955  815.073657
# 13       충청남도   2130119   2420  880.214463
# 14    전북특별자치도   1754757   2560  685.451953
# 15       전라남도   1804217   2127  848.244946
# 16       경상북도   2554324   2881  886.610205
# 17       경상남도   3251158   3820  851.088482
# 18    제주특별자치도    675252    958  704.855950

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

font_path = r'C:\Windows\Fonts\malgun.ttf' 
font_name = fm.FontProperties(fname=font_path, size=18).get_name()

mpl.rc('font', family=font_name, size=20) 

plt.figure(figsize=(12, 12))
plt.bar(pop['행정구역(시군구)별'], pop['병원 1개당 인구수'])
plt.xlabel('행정구역(시군구)')
plt.ylabel('단위: 명')
plt.title('병원 1곳당 인구수')
plt.xticks(rotation=90)
plt.show()
